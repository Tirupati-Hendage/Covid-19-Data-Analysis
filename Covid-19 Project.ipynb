# %% [markdown]
# # Covid-19 data analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('E:\\CSV folder\\country_wise_latest.csv')

# %%
data.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
#1.
#df.count()
#df.isnull().sum()

# %%
data.shape
# Out:
# (187, 15)

# %%
data.count()

#Null values means missing values
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.isnull()

#It will show the result in boolean forms
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0             False      False   False      False   False      False
# 1             False      False   False      False   False      False
# 2             False      False   False      False   False      False
# 3             False      False   False      False   False      False
# 4             False      False   False      False   False      False
# ..              ...        ...     ...        ...     ...        ...
# 182           False      False   False      False   False      False
# 183           False      False   False      False   False      False
# 184           False      False   False      False   False      False
# 185           False      False   False      False   False      False
# 186           False      False   False      False   False      False
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# ...

# %%
data.isnull().sum()
# Out:
# Country/Region            0
# Confirmed                 0
# Deaths                    0
# Recovered                 0
# Active                    0
# New cases                 0
# New deaths                0
# New recovered             0
# Deaths / 100 Cases        0
# Recovered / 100 Cases     0
# Deaths / 100 Recovered    0
# Confirmed last week       0
# 1 week change             0
# 1 week % increase         0
# WHO Region                0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Country/Region            187
# Confirmed                 187
# Deaths                    187
# Recovered                 187
# Active                    187
# New cases                 187
# New deaths                187
# New recovered             187
# Deaths / 100 Cases        187
# Recovered / 100 Cases     187
# Deaths / 100 Recovered    187
# Confirmed last week       187
# 1 week change             187
# 1 week % increase         187
# WHO Region                187
# dtype: int64

# %%
data.rename(columns={'Country/Region' : 'Country'}, inplace=True)

# %%
data.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
# 2      Algeria      27973    1163      18837    7973        616           8
# 3      Andorra        907      52        803      52         10           0
# 4       Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
sns.heatmap(data.isnull())

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe

# %%
data.drop(columns=['Confirmed last week', '1 week change', '1 week % increase'], inplace=True)

# %%
data.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0  Afghanistan      36263    1269      25198    9796        106          10
# 1      Albania       4880     144       2745    1991        117           6
# 2      Algeria      27973    1163      18837    7973        616           8
# 3      Andorra        907      52        803      52         10           0
# 4       Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered             WHO Region
# 0                    5.04  Eastern Mediterranean
# ...

# %%
data.drop(columns=['New cases', 'New deaths', 'New recovered'], inplace=True)

# %%
data.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 0  Afghanistan      36263    1269      25198    9796                3.50
# 1      Albania       4880     144       2745    1991                2.95
# 2      Algeria      27973    1163      18837    7973                4.16
# 3      Andorra        907      52        803      52                5.73
# 4       Angola        950      41        242     667                4.32
#
#    Recovered / 100 Cases  Deaths / 100 Recovered             WHO Region
# 0                  69.49                    5.04  Eastern Mediterranean
# 1                  56.25                    5.25                 Europe
# 2                  67.34                    6.17                 Africa
# 3                  88.53                    6.48                 Europe
# 4                  25.47                   16.94                 Africa

# %%
data.groupby('WHO Region').sum()
# Out:
#                        Confirmed  Deaths  Recovered   Active  \
# WHO Region
# Africa                    723197   12222     440637   270338
# Americas                 8839018  342727    4468408  4027883
# Eastern Mediterranean    1490744   38339    1201400   251005
# Europe                   3299411  211143    1993617  1094651
# South-East Asia          1835174   41349    1156847   636978
# Western Pacific           292319    8249     206722    77348
#
#                        Deaths / 100 Cases  Recovered / 100 Cases  \
# WHO Region
# Africa                             100.71                2656.71
# Americas                            99.18                1595.54
# Eastern Mediterranean               78.39                1465.05
# Europe                             233.95                3556.51
# South-East Asia                     12.96                 580.17
# Western Pacific                     20.64                1049.47
#
#                        Deaths / 100 Recovered
# ...

# %%
plt.figure(figsize=(16,9))
sns.set()
ax = sns.barplot(x='WHO Region', y='Confirmed', data=data)
ax.set(title = 'Barplot of Covid-19 Data',
      xlabel = 'WHO Region',
      ylabel = 'Confirmed Cases')
plt.show()

# %%
data.groupby('Country').sum().head(20)
# Out:
#                      Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# Country
# Afghanistan              36263    1269      25198    9796                3.50
# Albania                   4880     144       2745    1991                2.95
# Algeria                  27973    1163      18837    7973                4.16
# Andorra                    907      52        803      52                5.73
# Angola                     950      41        242     667                4.32
# Antigua and Barbuda         86       3         65      18                3.49
# Argentina               167416    3059      72575   91782                1.83
# Armenia                  37390     711      26665   10014                1.90
# Australia                15303     167       9311    5825                1.09
# Austria                  20558     713      18246    1599                3.47
# Azerbaijan               30446     423      23242    6781                1.39
# ...

# %%
data[data.Country == 'India']
# Out:
#    Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 79   India    1480073   33408     951166  495499                2.26
#
#     Recovered / 100 Cases  Deaths / 100 Recovered       WHO Region
# 79                  64.26                    3.51  South-East Asia

# %%
data.groupby('WHO Region')['Confirmed', 'Deaths'].sum()
# Out:
# <ipython-input-47-74193735e181>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('WHO Region')['Confirmed', 'Deaths'].sum()
#                        Confirmed  Deaths
# WHO Region
# Africa                    723207   12223
# Americas                 8839286  342732
# Eastern Mediterranean    1490744   38339
# Europe                   3299523  211144
# South-East Asia          1835297   41349
# Western Pacific           292428    8249

# %%
data.groupby('Country')['Confirmed', 'Deaths'].sum().sort_values(by = 'Confirmed', ascending=False).head(20)
# Out:
# <ipython-input-52-314e6b9746ec>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Country')['Confirmed', 'Deaths'].sum().sort_values(by = 'Confirmed', ascending=False).head(20)
#                 Confirmed  Deaths
# Country
# US                4290259  148011
# Brazil            2442375   87618
# India             1480073   33408
# Russia             816680   13334
# South Africa       452529    7067
# Mexico             395489   44022
# Peru               389717   18418
# Chile              347923    9187
# United Kingdom     301708   45844
# Iran               293606   15912
# Pakistan           274289    5842
# Spain              272421   28432
# Saudi Arabia       268934    2760
# Colombia           257101    8777
# Italy              246286   35112
# Turkey             227019    5630
# Bangladesh         226225    2965
# France             220352   30212
# ...

# %%
data.head()
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 0  Afghanistan      36263    1269      25198    9796                3.50
# 1      Albania       4880     144       2745    1991                2.95
# 2      Algeria      27973    1163      18837    7973                4.16
# 3      Andorra        907      52        803      52                5.73
# 4       Angola        950      41        242     667                4.32
#
#    Recovered / 100 Cases  Deaths / 100 Recovered             WHO Region
# 0                  69.49                    5.04  Eastern Mediterranean
# 1                  56.25                    5.25                 Europe
# 2                  67.34                    6.17                 Africa
# 3                  88.53                    6.48                 Europe
# 4                  25.47                   16.94                 Africa

# %% [markdown]
# # Remove all the cases where Confirmed cases are less than 100

# %%
(data.Confirmed < 100).sum()
# Out:
# 16

# %%
data[data.Confirmed < 100]
# Out:
#                               Country  Confirmed  Deaths  Recovered  Active  \
# 5                 Antigua and Barbuda         86       3         65      18
# 17                             Belize         48       2         26      20
# 19                             Bhutan         99       0         86      13
# 49                           Dominica         18       0         18       0
# 59                               Fiji         27       0         18       9
# 68                          Greenland         14       0         13       1
# 69                            Grenada         23       0         23       0
# 75                           Holy See         12       0         12       0
# 94                               Laos         20       0         19       1
# 100                     Liechtenstein         86       1         81       4
# 130                  Papua New Guinea         62       0         11      51
# ...

# %%
data[~data.Confirmed < 100]
# Out:
#                 Country  Confirmed  Deaths  Recovered  Active  \
# 0           Afghanistan      36263    1269      25198    9796
# 1               Albania       4880     144       2745    1991
# 2               Algeria      27973    1163      18837    7973
# 3               Andorra        907      52        803      52
# 4                Angola        950      41        242     667
# ..                  ...        ...     ...        ...     ...
# 182  West Bank and Gaza      10621      78       3752    6791
# 183      Western Sahara         10       1          8       1
# 184               Yemen       1691     483        833     375
# 185              Zambia       4552     140       2815    1597
# 186            Zimbabwe       2704      36        542    2126
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                  3.50                  69.49                    5.04
# 1                  2.95                  56.25                    5.25
# ...

# %%
data = data[~(data.Confirmed < 100)]  # To remove the records satisying a particular condition

# %%
data.head(20)
# Out:
#                    Country  Confirmed  Deaths  Recovered  Active  \
# 0              Afghanistan      36263    1269      25198    9796
# 1                  Albania       4880     144       2745    1991
# 2                  Algeria      27973    1163      18837    7973
# 3                  Andorra        907      52        803      52
# 4                   Angola        950      41        242     667
# 6                Argentina     167416    3059      72575   91782
# 7                  Armenia      37390     711      26665   10014
# 8                Australia      15303     167       9311    5825
# 9                  Austria      20558     713      18246    1599
# 10              Azerbaijan      30446     423      23242    6781
# 11                 Bahamas        382      11         91     280
# 12                 Bahrain      39482     141      36110    3231
# 13              Bangladesh     226225    2965     125683   97577
# ...

# %% [markdown]
# # In which Region maximun number of confirmed cases were recorded ?

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 0  Afghanistan      36263    1269      25198    9796                3.50
# 1      Albania       4880     144       2745    1991                2.95
#
#    Recovered / 100 Cases  Deaths / 100 Recovered             WHO Region
# 0                  69.49                    5.04  Eastern Mediterranean
# 1                  56.25                    5.25                 Europe

# %%
data.groupby('WHO Region').Confirmed.sum().sort_values(ascending=False) #by WHO Region
# Out:
# WHO Region
# Americas                 8839018
# Europe                   3299411
# South-East Asia          1835174
# Eastern Mediterranean    1490744
# Africa                    723197
# Western Pacific           292319
# Name: Confirmed, dtype: int64

# %%
data.groupby('Country').Confirmed.sum().sort_values(ascending=False).head(20)  # by Country
# Out:
# Country
# US                4290259
# Brazil            2442375
# India             1480073
# Russia             816680
# South Africa       452529
# Mexico             395489
# Peru               389717
# Chile              347923
# United Kingdom     301708
# Iran               293606
# Pakistan           274289
# Spain              272421
# Saudi Arabia       268934
# Colombia           257101
# Italy              246286
# Turkey             227019
# Bangladesh         226225
# France             220352
# Germany            207112
# Argentina          167416
# Name: Confirmed, dtype: int64

# %% [markdown]
# # In which Region, minimum number of Death cases were recorded?

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 0  Afghanistan      36263    1269      25198    9796                3.50
# 1      Albania       4880     144       2745    1991                2.95
#
#    Recovered / 100 Cases  Deaths / 100 Recovered             WHO Region
# 0                  69.49                    5.04  Eastern Mediterranean
# 1                  56.25                    5.25                 Europe

# %%
data.groupby('WHO Region').Deaths.sum().sort_values() #by WHO Region
# Out:
# WHO Region
# Western Pacific            8249
# Africa                    12222
# Eastern Mediterranean     38339
# South-East Asia           41349
# Europe                   211143
# Americas                 342727
# Name: Deaths, dtype: int64

# %%
data.groupby('Country').Deaths.sum().sort_values(ascending=True).head(20) # by Country
# Out:
# Country
# Mongolia                0
# Eritrea                 0
# Seychelles              0
# Vietnam                 0
# Cambodia                0
# Burundi                 1
# Uganda                  2
# Botswana                2
# Brunei                  3
# Monaco                  4
# Rwanda                  5
# Burma                   6
# Taiwan*                 7
# Comoros                 7
# Barbados                7
# Gambia                  8
# Namibia                 8
# Trinidad and Tobago     8
# Malta                   9
# Iceland                10
# Name: Deaths, dtype: int64

# %%
data.head(2)
# Out:
#        Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 0  Afghanistan      36263    1269      25198    9796                3.50
# 1      Albania       4880     144       2745    1991                2.95
#
#    Recovered / 100 Cases  Deaths / 100 Recovered             WHO Region
# 0                  69.49                    5.04  Eastern Mediterranean
# 1                  56.25                    5.25                 Europe

# %% [markdown]
# # How many Confirmed, Deaths & Recovered cases reported in India

# %%
data[data.Country == 'India']
# Out:
#    Country  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 79   India    1480073   33408     951166  495499                2.26
#
#     Recovered / 100 Cases  Deaths / 100 Recovered       WHO Region
# 79                  64.26                    3.51  South-East Asia

# %% [markdown]
# # Sort the entire data wrt number of Confirmed cases in ascending order

# %%
data.sort_values(by = ['Confirmed'], ascending=True).head(20)
# Out:
#                  Country  Confirmed  Deaths  Recovered  Active  \
# 14              Barbados        110       7         94       9
# 148           Seychelles        114       0         39      75
# 113               Monaco        116       4        104       8
# 24                Brunei        141       3        138       0
# 170  Trinidad and Tobago        148       8        128      12
# 30              Cambodia        226       0        147      79
# 55               Eritrea        265       0        191      74
# 114             Mongolia        289       0        222      67
# 63                Gambia        326       8         66     252
# 110            Mauritius        344      10        332       2
# 27                 Burma        350       6        292      52
# 38               Comoros        354       7        328      19
# 28               Burundi        378       1        301      76
# 11               Bahamas        382      11         91     280
# ...

# %% [markdown]
# # Sort the entire data wrt. no. of Recovered cases in descending order.

# %%
data.sort_values(by = ['Recovered'], ascending=False).head(20)
# Out:
#           Country  Confirmed  Deaths  Recovered   Active  Deaths / 100 Cases  \
# 23         Brazil    2442375   87618    1846641   508116                3.59
# 173            US    4290259  148011    1325804  2816444                3.45
# 79          India    1480073   33408     951166   495499                2.26
# 138        Russia     816680   13334     602249   201097                1.63
# 35          Chile     347923    9187     319954    18782                2.64
# 111        Mexico     395489   44022     303810    47657               11.13
# 154  South Africa     452529    7067     274925   170537                1.56
# 132          Peru     389717   18418     272547    98752                4.73
# 81           Iran     293606   15912     255144    22550                5.42
# 128      Pakistan     274289    5842     241026    27421                2.13
# 145  Saudi Arabia     268934    2760     222936    43238                1.03
# ...
